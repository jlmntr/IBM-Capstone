# %% [markdown]
# # IBM Data Science Coursera Capstone Project

# %% [markdown]
# # Table of Contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)
# ___

# %% [markdown]
# # Introduction: Business Problem<a id='introduction'></a>
#
# Jakarta is the capital of Indonesia with a population of 10,5 million, and is the heart of the second densest metropolitan area in the world behind Tokyo, Japan. Having hosted ASEAN games recently back in 2018, it has witnessed heavy investment in transportational infrastructure with the opening of the first MRT line in Indonesia just this year.
#
# Given that, the city will surely see more growth of which information regarding the lay of the land will be invaluable for investors and entrepreneurs to make strategic decision for investment or choosing locations for business operation.
#
# This project will attempt to explore patterns of subdistricts within Jakarta by categorizing them into clusters in order to identify existing trends within neighborhoods of Jakarta. From there on, recommendations can be made on which category of neighborhood will be most suitable for a certain type of venue to be opened.
#
# The result of this project is aimed at general entrepreneur but may be most useful for entrepreneurs on the food and beverage sector given that location can be the deciding factor for a success.
# ___

# %% [markdown]
# # Data<a id='data'></a>
#
# To analyze trends in Jakarta's subdistrict, the list of subdistrict is obtained from [Jakarta subdistrict wikipedia page](https://en.wikipedia.org/wiki/Subdistricts_of_Jakarta).
#
# Venue queries will then be made by subdistricts using FourSquare APIs. The resulting data regarding venue category will be used to observe commonality between subdistricts. The commonality clusters can then provide insight on which type of venue will thrive better on which cluster. K-means clustering algorithm will be used to find pattern between the subdistricts.
#
# In summary, the following data is required to meet the objective:
#
# - Subdistricts of Jakarta
# - Coordinates of these subdistricts
# - Trending Venues on the area
# - Venue categories
#
# ___

# %% [markdown]
# # Methodology<a id='methodology'></a>
#
# Given that our objective is to generally categorize the subdistricts, we will use K-means clustering algorithm to categorize each of the subdistricts within Jakarta.
#
# A one-hot encoding will be done on the venue dataframe and it will be grouped by subdistrict. The encoding will return venue categories as column per subdistrict, which will then be grouped to provide weighting of venue type occurence on each subdistrict.
#
# The encoded dataframe will be further filtered into top venues before the K-means clustering algorithm will be run over it. This will return cluster labels over the subdistricts. The clusters will be observed one by one manually to determine its content.
#
# Recommendation will be made based on the clusterring.

# %% [markdown]
# # Analysis<a id='analysis'></a>

# %% [markdown]
# ## Map of Clusters

# %%
# create map
map_clusters = folium.Map(location=jakarta["DKI Jakarta"], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(jakarta_merged['Latitude'], jakarta_merged['Longitude'], jakarta_merged['Subdistrict'], jakarta_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine Clusters

# %% [markdown]
# Examine each clusters.

# %% [markdown]
# #### Cluster 1
#
# Cluster 1 contains a higher concentration of noodle house and chinese restaurant. Located north of Jakarta, this might be the cluster for Chinese restaurants.

# %%
jakarta_merged.loc[jakarta_merged['Cluster Labels'] == 1, jakarta_merged.columns[[0] + list(range(4, jakarta_merged.shape[1]))]]
# Out:
#           Subdistrict 1st Most Common Venue 2nd Most Common Venue  \
# 1   Grogol Petamburan          Noodle House           Coffee Shop
# 6          Taman Sari    Chinese Restaurant          Noodle House
# 7             Tambora    Chinese Restaurant          Noodle House
# 12        Sawah Besar    Chinese Restaurant          Noodle House
# 40        Penjaringan    Seafood Restaurant    Chinese Restaurant
# 41      Tanjung Priok      Asian Restaurant    Chinese Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 1     Chinese Restaurant        Clothing Store       Asian Restaurant
# 6       Asian Restaurant                 Hotel     Seafood Restaurant
# 7       Asian Restaurant                 Hotel            Coffee Shop
# 12                 Hotel    Seafood Restaurant            Coffee Shop
# 40          Noodle House           Coffee Shop                   Café
# 41          Noodle House    Seafood Restaurant  Indonesian Restaurant
#
#     6th Most Common Venue 7th Most Common Venue  8th Most Common Venue  \
# 1      Seafood Restaurant            Restaurant  Indonesian Restaurant
# 6                  Bakery           Coffee Shop   Fast Food Restaurant
# 7                  Bakery            Food Truck  Indonesian Restaurant
# 12  Indonesian Restaurant             BBQ Joint       Asian Restaurant
# 40  Indonesian Restaurant                Bakery             Restaurant
# 41            Pizza Place                 Beach         Massage Studio
#
#    9th Most Common Venue         10th Most Common Venue
# 1             Steakhouse              Korean Restaurant
# 6              Hotel Bar                     Steakhouse
# 7             Steakhouse                 Massage Studio
# 12                  Café                     Restaurant
# 40   Balinese Restaurant  Vegetarian / Vegan Restaurant
# 41                  Café                     Restaurant

# %% [markdown]
# #### Cluster 2
#
# With the most member, cluster 2 seems to contain a good amount of coffee shops and hotels. Located central-south of the city, it is expected to have a high concentration of places to hang out and stay.

# %%
jakarta_merged.loc[jakarta_merged['Cluster Labels'] == 2, jakarta_merged.columns[[0] + list(range(4, jakarta_merged.shape[1]))]]
# Out:
#          Subdistrict  1st Most Common Venue  2nd Most Common Venue  \
# 5           Palmerah            Coffee Shop       Asian Restaurant
# 8      Cempaka Putih  Indonesian Restaurant            Pizza Place
# 9             Gambir                  Hotel  Indonesian Restaurant
# 10        Johar Baru  Indonesian Restaurant                  Hotel
# 11         Kemayoran                  Hotel  Indonesian Restaurant
# 13             Senen  Indonesian Restaurant            Coffee Shop
# 14       Tanah Abang            Coffee Shop                  Hotel
# 15          Cilandak            Coffee Shop       Asian Restaurant
# 17    Kebayoran Baru  Indonesian Restaurant            Coffee Shop
# 18    Kebayoran Lama            Coffee Shop  Indonesian Restaurant
# 19  Mampang Prapatan            Coffee Shop             Restaurant
# 20          Pancoran            Coffee Shop       Asian Restaurant
# 21      Pasar Minggu  Indonesian Restaurant             Food Truck
# 23         Setiabudi            Coffee Shop                  Hotel
# 24             Tebet  Indonesian Restaurant            Coffee Shop
# 29        Jatinegara            Coffee Shop  Indonesian Restaurant
# 30       Kramat Jati   Fast Food Restaurant  Indonesian Restaurant
# 33           Menteng  Indonesian Restaurant                  Hotel
# 37     Kelapa Gading            Coffee Shop  Indonesian Restaurant
# 39        Pademangan     Seafood Restaurant                  Hotel
#
#         3rd Most Common Venue  4th Most Common Venue  5th Most Common Venue  \
# 5       Indonesian Restaurant                  Hotel      Convenience Store
# 8                 Coffee Shop   Fast Food Restaurant                  Hotel
# 9                 Coffee Shop     Seafood Restaurant       Asian Restaurant
# 10                   Pharmacy     Seafood Restaurant            Pizza Place
# 11  Indonesian Meatball Place       Asian Restaurant             Food Court
# 13                      Hotel                   Café   Fast Food Restaurant
# 14      Indonesian Restaurant    Japanese Restaurant             Restaurant
# 15                       Café             Food Truck  Indonesian Restaurant
# 17        Japanese Restaurant                  Hotel           Noodle House
# 18             Clothing Store                   Café                 Bakery
# 19                      Hotel       Asian Restaurant             Food Truck
# 20          Convenience Store                   Café   Fast Food Restaurant
# 21                Coffee Shop    Japanese Restaurant      Convenience Store
# 23         Italian Restaurant  Indonesian Restaurant     Chinese Restaurant
# 24             Clothing Store           Dessert Shop                   Café
# 29           Asian Restaurant   Fast Food Restaurant             Food Truck
# 30                 Restaurant                 Bakery       Asian Restaurant
# 33                Coffee Shop  Betawinese Restaurant   Fast Food Restaurant
# 37               Noodle House       Asian Restaurant                 Bakery
# 39               Noodle House     Chinese Restaurant  Indonesian Restaurant
#
#     6th Most Common Venue  7th Most Common Venue  \
# 5              Food Truck                   Café
# 8        Asian Restaurant                   Café
# 9    Fast Food Restaurant           Camera Store
# 10             Restaurant      Convenience Store
# 11     Seafood Restaurant     Chinese Restaurant
# 13              Bookstore             Restaurant
# 14                 Lounge               Building
# 15   Fast Food Restaurant             Steakhouse
# 17             Food Truck       Sushi Restaurant
# 18          Shopping Mall            Pizza Place
# 19             Steakhouse  Indonesian Restaurant
# 20  Indonesian Restaurant            Supermarket
# 21     Chinese Restaurant           Noodle House
# 23    Japanese Restaurant   Fast Food Restaurant
# 24                 Bakery    Japanese Restaurant
# 29                   Café             Donut Shop
# 30     Seafood Restaurant          Shopping Mall
# 33                   Café             Steakhouse
# 37          Shopping Mall      Korean Restaurant
# 39            Coffee Shop             Theme Park
#
#            8th Most Common Venue      9th Most Common Venue  \
# 5             Chinese Restaurant                Pizza Place
# 8                     Restaurant  Indonesian Meatball Place
# 9             Chinese Restaurant                 Restaurant
# 10                     BBQ Joint     Furniture / Home Store
# 11             Convenience Store               Cupcake Shop
# 13              Asian Restaurant                     Bakery
# 14            Italian Restaurant         Chinese Restaurant
# 15               Motorcycle Shop         Chinese Restaurant
# 17                     BBQ Joint             Breakfast Spot
# 18              Sushi Restaurant        Japanese Restaurant
# 19                        Bakery       Fast Food Restaurant
# 20                  Noodle House                      Hotel
# 21                          Café                     Bakery
# 23                     BBQ Joint  Indonesian Meatball Place
# 24                    Restaurant                Pizza Place
# 29                           Spa              Shopping Mall
# 30                     BBQ Joint        Fried Chicken Joint
# 33                History Museum                 Food Truck
# 37              Sushi Restaurant        Japanese Restaurant
# 39  Theme Park Ride / Attraction           Asian Restaurant
#
#    10th Most Common Venue
# 5          Clothing Store
# 8              Food Truck
# 9              Soup Place
# 10            Coffee Shop
# 11                    Gym
# 13     Chinese Restaurant
# 14         Breakfast Spot
# 15                 Bakery
# 17           Burger Joint
# 18           Dessert Shop
# 19    Japanese Restaurant
# 20            Pizza Place
# 21   Fast Food Restaurant
# 23                 Lounge
# 24             Food Truck
# 29          Movie Theater
# 30             Donut Shop
# 33         Sandwich Place
# 37              BBQ Joint
# 39  General Entertainment

# %% [markdown]
# #### Cluster 3
#
# Containing only 1 subdistrict, cluster 3 seems to be in its own group located at the south of the city. This might be due to the low count of trending venues of 10. Nothing much can be gathered from this cluster.

# %%
jakarta_merged.loc[jakarta_merged['Cluster Labels'] == 3, jakarta_merged.columns[[0] + list(range(4, jakarta_merged.shape[1]))]]
# Out:
#    Subdistrict 1st Most Common Venue 2nd Most Common Venue  \
# 16   Jagakarsa     Convenience Store          Burger Joint
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 16            Food Truck            Theme Park            Restaurant
#
#    6th Most Common Venue 7th Most Common Venue   8th Most Common Venue  \
# 16          Noodle House  Fast Food Restaurant  College Residence Hall
#
#    9th Most Common Venue 10th Most Common Venue
# 16  Other Great Outdoors            Flower Shop

# %% [markdown]
# #### Cluster 4
#
# Having commonality with cluster 3 with Indonesian restaurants as its common venue, cluster 4 have higher count of convenience store in general. The subdistricts within this cluster are more scatered, being dispersed on around the border surrounding cluster 2

# %%
jakarta_merged.loc[jakarta_merged['Cluster Labels'] == 4, jakarta_merged.columns[[0] + list(range(4, jakarta_merged.shape[1]))]]
# Out:
#      Subdistrict      1st Most Common Venue  2nd Most Common Venue  \
# 0     Cengkareng               Noodle House       Asian Restaurant
# 2      Kalideres               Noodle House       Asian Restaurant
# 3    Kebon Jeruk           Asian Restaurant      Convenience Store
# 4      Kembangan             Shop & Service    Japanese Restaurant
# 22  Pesanggrahan                 Food Truck           Noodle House
# 26      Cipayung      Indonesian Restaurant      Convenience Store
# 27       Ciracas       Fast Food Restaurant            Coffee Shop
# 28   Duren Sawit  Indonesian Meatball Place   Fast Food Restaurant
# 31       Makasar      Indonesian Restaurant   Fast Food Restaurant
# 32      Matraman      Indonesian Restaurant       Asian Restaurant
# 34    Pasar Rebo      Indonesian Restaurant   Fast Food Restaurant
# 35   Pulo Gadung               Noodle House  Indonesian Restaurant
#
#     3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 0                    Café            Pizza Place                   Bar
# 2             Coffee Shop            Pizza Place  Fast Food Restaurant
# 3   Indonesian Restaurant            Coffee Shop           Pizza Place
# 4             Snack Place             Soup Place           Gas Station
# 22   Fast Food Restaurant  Indonesian Restaurant     Convenience Store
# 26                 Garden                 Arcade           High School
# 27           Noodle House      Convenience Store      Asian Restaurant
# 28     Salon / Barbershop      Convenience Store            Food Truck
# 31            Golf Course           Noodle House           Pizza Place
# 32            Pizza Place      Convenience Store           Coffee Shop
# 34     Seafood Restaurant           Dessert Shop      Baseball Stadium
# 35            Coffee Shop             Food Truck    Chinese Restaurant
#
#     6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 0                  Bistro     Seafood Restaurant  Indonesian Restaurant
# 2              Food Court             Food Truck      Convenience Store
# 3              Steakhouse           Noodle House                   Café
# 4                   Plaza                  Diner                   Park
# 22             Food Court                   Café      Electronics Store
# 26            Pizza Place       Asian Restaurant      Food & Drink Shop
# 27  Indonesian Restaurant             Water Park              Rest Area
# 28           Noodle House  Indonesian Restaurant     Seafood Restaurant
# 31       Asian Restaurant              Bookstore    Monument / Landmark
# 32               Pharmacy     Seafood Restaurant                   Café
# 34             Food Truck           Noodle House      Convenience Store
# 35       Asian Restaurant     Seafood Restaurant                   Café
#
#    9th Most Common Venue 10th Most Common Venue
# 0             Steakhouse                    Gym
# 2    Japanese Restaurant                   Café
# 3     Seafood Restaurant   Fast Food Restaurant
# 4      Convenience Store  Indonesian Restaurant
# 22      Asian Restaurant                 Bakery
# 26          Noodle House             Food Stand
# 27                Garden     Dim Sum Restaurant
# 28      Asian Restaurant       Department Store
# 31            Food Truck            Music Venue
# 32  Fast Food Restaurant           Noodle House
# 34               Factory                   Café
# 35            Soup Place      Convenience Store

# %% [markdown]
# #### Cluster 5
#
# Similar with cluster 3 with only 1 subdistrict, cluster 5 seems to be in its own group located at the north east of the city. This might be due to the low count of trending venues of 15. Nothing much can be gathered from this cluster.

# %%
jakarta_merged.loc[jakarta_merged['Cluster Labels'] == 5, jakarta_merged.columns[[0] + list(range(4, jakarta_merged.shape[1]))]]
# Out:
#    Subdistrict      1st Most Common Venue  2nd Most Common Venue  \
# 38        Koja  Indonesian Meatball Place  Indonesian Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 38           Pizza Place            Restaurant     Convenience Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 38      Satay Restaurant                Bakery           High School
#
#    9th Most Common Venue 10th Most Common Venue
# 38   Government Building      Food & Drink Shop

# %% [markdown]
# # Result and Discussion<a id='results'></a>
#
# Groupings as a result of K-means clustering algorithm tallies with how Jakarta historically develops. Having most of cluster 1, containing a high count of chinese restaurant, at the north side of the city fits the chinatown part of the city. Cluster 2 being the dominant type of subdistrict which is located in the middle also fits the reality. North eastern part being quite sparse in trending venue also fits the reality that the area is more of an industrial area, thus having less venues.
#
# There are definite limitation with using the FourSquare API as the 100 venues limit might skew the result of the more densely populated subdistrict. Also, some subdistricts have low count of venues that it might be considered to be insufficient in determining its characteristics. It might also be the case that FourSquare user base are skewed to the foodie type, which might explain the limited trending venues on the north east part of the city.
#
# For most of the subdistricts, restaurants and coffee shops are the dominant venue type with cluster 2 having more variation in terms of cuisine.

# %% [markdown]
# # Conclusion<a id='conclusion'></a>
#
# Opening of new western restaurant may be best done in cluster 5 where there are less of such restaurant to compete. Business which does not rely on foot traffic may choose to locate themself in the north east of Jakarta.
